# %%
dont_worry = "Don't worry about single quotes if the string is in double quotes, and vice versa"
print(dont_worry)

print("\"Sweet\" is an ice-cream")

print("Sweet\'n\'Tasty")
# Out:
# Don't worry about single quotes if the string is in double quotes, and vice versa
# "Sweet" is an ice-cream
# Sweet'n'Tasty
