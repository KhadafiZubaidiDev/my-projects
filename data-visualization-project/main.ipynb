# %% [markdown]
# # Deskripsi

# %% [markdown]
# ## Deskripsi Project
# Pelajari dan gunakan dataset Credit Card Customers yang tersedia di:
# https://www.kaggle.com/datasets/sakshigoyal7/credit-card-customers.
# Buatlah visualisasi dengan menggunakan python (library matplotlib/seaborn) dari berbagai kolom/variable sesuai perintah berikut:
#
#
# 1.   [50 poin] Buatlah 5 visualisasi masing-masing untuk kolom attrition_flag, customer_age,gender, education_level, dan income_category. (Wajib ada pie chart, donut chart, vertical bar chart, dan horizontal bar…untuk No. 1.
# 3.   [10 poin] Buatlah 1 visualisasi menggunakan countplot yang memadukan lebih dari satu kolom (bebas antar kolom yang mana saja)
# 4.   [10 poin] Buatlah 1 visualisasi menggunakan scatterplot yang memadukan lebih darisatu kolom (bebas antar kolom yang mana saja)
# 5.   [10 poin] Buatlah 1 visualisasi menggunakan heatmap yang memadukan lebih dari satu kolom (bebas antar kolom yang mana saja)
# 6.   [15 poin] Tuliskan informasi dan insight darisetiap visualisasi yang dibuat untuk No. 3-5.

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# # Memanggil Data

# %%
df = pd.read_csv('BankChurners.csv')

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %% [markdown]
# # Informasi Umum Dataframe

# %%
df.shape
# Out:
# (10127, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
df['Attrition_Flag'].unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
df['Customer_Age'].unique()
# Out:
# array([45, 49, 51, 40, 44, 32, 37, 48, 42, 65, 56, 35, 57, 41, 61, 47, 62,
#        54, 59, 63, 53, 58, 55, 66, 50, 38, 46, 52, 39, 43, 64, 68, 67, 60,
#        73, 70, 36, 34, 33, 26, 31, 29, 30, 28, 27])

# %%
df['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df['Education_Level'].unique()
# Out:
# array(['High School', 'Graduate', 'Uneducated', 'Unknown', 'College',
#        'Post-Graduate', 'Doctorate'], dtype=object)

# %%
df['Income_Category'].unique()
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        '$120K +', 'Unknown'], dtype=object)

# %% [markdown]
# # Hitung Prosentase Nilai Unique
# Sebelum kita membuat chart dari kolom-kolom attrition_flag, customer_age,gender, education_level, dan income_category, kita akan menghitung masing-masing prosentase nilai unique dari masing-masing kolom sebagai informasi pendukung

# %%
persentase_attrition_flag = df['Attrition_Flag'].value_counts(normalize=True) * 100
persentase_attrition_flag
# Out:
# Attrition_Flag
# Existing Customer    83.934038
# Attrited Customer    16.065962
# Name: proportion, dtype: float64

# %%
persentase_customer_age = df['Customer_Age'].value_counts(normalize=True) * 100
persentase_customer_age
# Out:
# Customer_Age
# 44    4.937296
# 49    4.887923
# 46    4.838550
# 45    4.799052
# 47    4.729930
# 43    4.670682
# 48    4.660808
# 50    4.463316
# 42    4.206576
# 51    3.930088
# 53    3.821467
# 41    3.742471
# 52    3.712847
# 40    3.564728
# 39    3.288239
# 54    3.031500
# 38    2.992002
# 55    2.755011
# 56    2.587143
# 37    2.567394
# 57    2.202034
# 36    2.182285
# 35    1.816925
# 59    1.550311
# 58    1.550311
# 34    1.441691
# 33    1.254073
# 60    1.254073
# 32    1.046707
# 65    0.997334
# 61    0.918337
# 62    0.918337
# 31    0.898588
# 26    0.770218
# 30    0.691221
# 63    0.641849
# 29    0.552977
# 64    0.424607
# 27    0.315987
# 28    0.286363
# 67    0.039498
# 66    0.019749
# 68    0.019749
# 70    0.009875
# 73    0.009875
# Name: proportion, dtype: float64

# %%
persentase_gender = df['Gender'].value_counts(normalize=True) * 100
persentase_gender
# Out:
# Gender
# F    52.908068
# M    47.091932
# Name: proportion, dtype: float64

# %%
persentase_education_level = df['Education_Level'].value_counts(normalize=True) * 100
persentase_education_level
# Out:
# Education_Level
# Graduate         30.887726
# High School      19.877555
# Unknown          14.999506
# Uneducated       14.683519
# College          10.002962
# Post-Graduate     5.095290
# Doctorate         4.453441
# Name: proportion, dtype: float64

# %%
persentase_income_category = df['Income_Category'].value_counts(normalize=True) * 100
persentase_income_category
# Out:
# Income_Category
# Less than $40K    35.163425
# $40K - $60K       17.675521
# $80K - $120K      15.157500
# $60K - $80K       13.844179
# Unknown           10.980547
# $120K +            7.178829
# Name: proportion, dtype: float64

# %% [markdown]
# # Jawaban No. 1
# Soal : [50 poin] Buatlah 5 visualisasi masing-masing untuk kolom attrition_flag, customer_age,gender, education_level, dan income_category. (Wajib ada pie chart, donut chart, vertical bar chart, dan horizontal bar chart).

# %% [markdown]
# ### Chart Kolom Attrition Flag

# %% [markdown]
# #### Pie Chart

# %%
fig,ax = plt.subplots()
ax.pie(df['Attrition_Flag'].value_counts(), explode={0,0.1},labels=df['Attrition_Flag'].value_counts().index,autopct='%1.1f%%',colors=['gold','mistyrose'],shadow=True,textprops={'size': 'smaller'})
ax.axis('equal')
ax.legend()
ax.set_title('Distribusi Attrition Flag')
# Out:
# Text(0.5, 1.0, 'Distribusi Attrition Flag')

# %% [markdown]
# #### Donut Chart

# %%
fig, ax = plt.subplots(figsize=(10, 6), subplot_kw=dict(aspect="equal"))
wedges, texts = ax.pie(df['Attrition_Flag'].value_counts(), wedgeprops=dict(width=0.7, edgecolor='w'), colors=['gold','mistyrose'])
# Inner circle
centre_circle = plt.Circle((0,0),0.40,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Add labels
labels = df['Attrition_Flag'].value_counts().index + " ( " + persentase_attrition_flag.astype(str) + " %)"
ax.legend(wedges, labels,
      title="Attrition Flag",
      loc="center left",
      bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(texts, size=12, weight="bold")

ax.set_title("Distribusi Attrition Flag")
ax.axis('equal')

plt.show()

# %% [markdown]
# #### Vertical Bar Chart

# %%
ax = df['Attrition_Flag'].value_counts().plot(kind='bar',color=['gold','mistyrose'], figsize=(15,15))
ax.set_title('Distribusi Attrition Flag')
ax.set_ylabel('Jumlah')
ax.set_xlabel('Attrition Flag')
plt.show()

# %% [markdown]
# #### Horizontal Bar Chart

# %%
ax = df['Attrition_Flag'].value_counts().plot(kind='barh',color=['gold','mistyrose'], figsize=(15,15))
ax.set_title('Distribusi Attrition Flag')
ax.set_xlabel('Jumlah')
ax.set_ylabel('Attrition Flag')
plt.show()

# %% [markdown]
# ### Chart Kolom Customer Age

# %% [markdown]
# #### Pie Chart

# %%
fig,ax = plt.subplots()
ax.pie(df['Customer_Age'].value_counts(), labels=df['Customer_Age'].value_counts().index)
ax.axis('equal')
ax.legend()
ax.set_title('Customer Age')
# Out:
# Text(0.5, 1.0, 'Customer Age')

# %% [markdown]
# #### Donut Chart

# %%
fig, ax = plt.subplots(figsize=(10, 6), subplot_kw=dict(aspect="equal"))
wedges, texts = ax.pie(df['Customer_Age'].value_counts(), wedgeprops=dict(width=0.7, edgecolor='w'))
# Inner circle
centre_circle = plt.Circle((0,0),0.40,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Add labels
labels = df['Customer_Age'].value_counts().index
ax.legend(wedges, labels,
      title="Customer Age",
      loc="center left",
      bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(texts, size=12, weight="bold")

ax.set_title("Distribusi Customer Age")
ax.axis('equal')

plt.show()

# %% [markdown]
# #### Vertical Bar Chart

# %%
ax = df['Customer_Age'].value_counts().plot(kind='bar', figsize=(15,15))
ax.set_title('Distribusi Customer Age')
ax.set_ylabel('Jumlah')
ax.set_xlabel('Customer Age')
plt.show()

# %% [markdown]
# #### Horizontal Bar Chart

# %%
ax = df['Customer_Age'].value_counts().plot(kind='barh',figsize=(15,15))
ax.set_title('Distribusi Customer Age')
ax.set_xlabel('Jumlah')
ax.set_ylabel('Customer Age')
plt.show()

# %% [markdown]
# ### Chart Kolom Gender

# %% [markdown]
# #### Pie Chart

# %%
fig,ax = plt.subplots()
ax.pie(df['Gender'].value_counts(), explode={0,0.1},labels=df['Gender'].value_counts().index,autopct='%1.1f%%',colors=['lightpink','lightblue'],shadow=True,textprops={'size': 'smaller'})
ax.axis('equal')
ax.legend()
ax.set_title('Gender')
# Out:
# Text(0.5, 1.0, 'Gender')

# %% [markdown]
# #### Donut Chart

# %%
fig, ax = plt.subplots(figsize=(10, 6), subplot_kw=dict(aspect="equal"))
wedges, texts = ax.pie(df['Gender'].value_counts(), wedgeprops=dict(width=0.7, edgecolor='w'), colors=['lightpink','lightblue'])
# Inner circle
centre_circle = plt.Circle((0,0),0.40,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Add labels
labels = df['Gender'].value_counts().index + " ( " + persentase_gender.astype(str) + " %)"
ax.legend(wedges, labels,
      title="Gender",
      loc="center left",
      bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(texts, size=12, weight="bold")

ax.set_title("Distribusi Gender")
ax.axis('equal')

plt.show()

# %% [markdown]
# #### Vertical Bar Chart

# %%
ax = df['Gender'].value_counts().plot(kind='bar',color=['lightpink','lightblue'], figsize=(15,15))
ax.set_title('Distribusi Gender')
ax.set_ylabel('Jumlah')
ax.set_xlabel('Gender')
plt.show()

# %% [markdown]
# #### Horizontal Bar Chart

# %%
ax = df['Gender'].value_counts().plot(kind='barh',color=['lightpink','lightblue'], figsize=(15,15))
ax.set_title('Distribusi Gender')
ax.set_xlabel('Jumlah')
ax.set_ylabel('Gender')
plt.show()

# %% [markdown]
# ### Chart Kolom Education Level

# %% [markdown]
# #### Pie Chart

# %%
fig,ax = plt.subplots()
ax.pie(df['Education_Level'].value_counts(), labels=df['Education_Level'].value_counts().index,autopct='%1.1f%%')
ax.axis('equal')
ax.legend()
ax.set_title('Education_Level')
# Out:
# Text(0.5, 1.0, 'Education_Level')

# %% [markdown]
# #### Donut Chart

# %%
fig, ax = plt.subplots(figsize=(10, 6), subplot_kw=dict(aspect="equal"))
wedges, texts = ax.pie(df['Education_Level'].value_counts(), wedgeprops=dict(width=0.7, edgecolor='w'))
# Inner circle
centre_circle = plt.Circle((0,0),0.40,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Add labels
labels = df['Education_Level'].value_counts().index + " ( " + persentase_education_level.astype(str) + " %)"
ax.legend(wedges, labels,
      title="Education Level",
      loc="center left",
      bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(texts, size=12, weight="bold")

ax.set_title("Distribusi Education Level")
ax.axis('equal')

plt.show()

# %% [markdown]
# #### Vertical Bar Chart

# %%
ax = df['Education_Level'].value_counts().plot(kind='bar',color=['lightpink','lightblue','orange','lime','navy','magenta','tomato'], figsize=(15,15))
ax.set_title('Distribusi Education Level')
ax.set_ylabel('Jumlah')
ax.set_xlabel('Education Level')
plt.show()

# %% [markdown]
# #### Horizontal Bar Chart

# %%
ax = df['Education_Level'].value_counts().plot(kind='barh',color=['lightpink','lightblue','orange','lime','navy','magenta','tomato'], figsize=(15,15))
ax.set_title('Distribusi Education Level')
ax.set_xlabel('Jumlah')
ax.set_ylabel('Education Level')
plt.show()

# %% [markdown]
# ### Chart Kolom Income Category

# %% [markdown]
# #### Pie Chart

# %%
fig,ax = plt.subplots()
ax.pie(df['Income_Category'].value_counts(), labels=df['Income_Category'].value_counts().index,autopct='%1.1f%%')
ax.axis('equal')
ax.legend()
ax.set_title('Income Category')
# Out:
# Text(0.5, 1.0, 'Income Category')

# %% [markdown]
# #### Donut Chart

# %%
fig, ax = plt.subplots(figsize=(10, 6), subplot_kw=dict(aspect="equal"))
wedges, texts = ax.pie(df['Income_Category'].value_counts(), wedgeprops=dict(width=0.7, edgecolor='w'))
# Inner circle
centre_circle = plt.Circle((0,0),0.40,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Add labels
labels = df['Income_Category'].value_counts().index + " ( " + persentase_income_category.astype(str) + " %)"
ax.legend(wedges, labels,
      title="Income Category",
      loc="center left",
      bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(texts, size=12, weight="bold")

ax.set_title("Distribusi Income Category")
ax.axis('equal')

plt.show()
