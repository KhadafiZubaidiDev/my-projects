# %%
coordinates = [1, 2, 3]

for coordinate1 in coordinates:
    for coordinate2 in coordinates:
        print(f'{coordinate1} x {coordinate2}')
# Out:
# 1 x 1
# 1 x 2
# 1 x 3
# 2 x 1
# 2 x 2
# 2 x 3
# 3 x 1
# 3 x 2
# 3 x 3
