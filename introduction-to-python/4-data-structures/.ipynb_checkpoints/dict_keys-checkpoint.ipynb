# %%
ages_dict = {
    "Alice": 21,
    "Bob": 39,
    "George": 30,
    "Susanne": 27,
    "Bob2": 19,
    "Ashley": 35,
    "Alex": 35,
    "Nancy": 35
}


if __name__ == "__main__":
    print(ages_dict.values())
# Out:
# dict_values([21, 39, 30, 27, 19, 35, 35, 35])
