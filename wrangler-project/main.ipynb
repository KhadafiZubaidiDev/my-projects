# %% [markdown]
# # Deskripsi

# %% [markdown]
# ## Deskripsi Project
# Project ini merupakan salah satu tugas Mini Project pada Kelas Data Science & AI Fundamentals Batch 42 yang diselenggarakan oleh DigitalSkola. Mini Project ini dikerjakan oleh : Khadafi Zubaidi.
#
# Dalam project ini dijelaskan mengenai langkah-langkah untuk membersihkan data, menampilkan data, serta melakukan analisis data eksploratif menggunakan bahasa pemrograman Python dan file data berekstensi csv.

# %% [markdown]
# # Import Library

# %% [markdown]
# ## Penjelasan
# Library yang digunakan dalam project ini adalah Pandas. Pandas adalah pustaka Python yang digunakan untuk mengolah data, seperti menganalisis, membersihkan, menjelajahi, dan memanipulasi data. Nama Pandas berasal dari singkatan "Panel Data" dan "Python Data Analysis"

# %%
import pandas as pd

# %% [markdown]
# # Memanggil Data

# %% [markdown]
# ## Penjelasan
# Setelah dilakukan import library pandas, selanjutnya kita akan memanggil data-data pada file csv kemudian disimpan ke dalam variabel df (dataframe). Hal ini diperlukan untuk pengelolaan data selanjutnya.

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ds42/Mobile_phone_price.csv')
