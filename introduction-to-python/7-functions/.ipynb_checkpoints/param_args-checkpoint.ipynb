# %%
def foo(x):  # x is a function parameter
    print("x = " + str(x))


foo(5)  # Pass 5 to foo(). Here 5 is an argument passed to function foo.


def square(x):
    print(x ** 2)


square(4)
square(8)
square(15)
square(23)
square(42)
# Out:
# x = 5
# 16
# 64
# 225
# 529
# 1764
