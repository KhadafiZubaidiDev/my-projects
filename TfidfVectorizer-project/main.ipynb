# %%
from sklearn.feature_extraction.text import TfidfVectorizer
corpus = [
    'Ini adalah dokumen pertama.',
    'Dokumen ini adalah dokumen kedua.',
    'Dan ini adalah dokumen ketiga.',
    'Apakah ini dokumen pertama?'
]

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)
print(vectorizer.get_feature_names_out())
print(X.toarray())
# Out:
# ['adalah' 'apakah' 'dan' 'dokumen' 'ini' 'kedua' 'ketiga' 'pertama']
# [[0.50881901 0.         0.         0.41599288 0.41599288 0.
#   0.         0.6284927 ]
#  [0.38357855 0.         0.         0.6272012  0.3136006  0.60094992
#   0.         0.        ]
#  [0.37149619 0.         0.58202057 0.30372248 0.30372248 0.
#   0.58202057 0.        ]
#  [0.         0.67943473 0.         0.35455723 0.35455723 0.
#   0.         0.53567415]]
