# %%
import sys
import datetime

print(sys.path)
print(datetime.datetime.today())
# Out:
# ['/Users/khadafizubaidi/Downloads/my-projects/introduction-to-python/9-modules-and-packages', '/opt/anaconda3/lib/python312.zip', '/opt/anaconda3/lib/python3.12', '/opt/anaconda3/lib/python3.12/lib-dynload', '', '/opt/anaconda3/lib/python3.12/site-packages', '/opt/anaconda3/lib/python3.12/site-packages/aeosa']
# 2024-10-26 05:58:21.206057
