# %%
two = 2
three = 3

is_equal = two == three
print(f"is_equal = {is_equal}")

is_false = is_equal is True # a boolean value for truthful statements
print(f"is_false = {is_false}")

is_true = is_false is False # a boolean value for not so truthful statements
print(f"is_true = {is_true}")
# Out:
# is_equal = False
# is_false = False
# is_true = True
